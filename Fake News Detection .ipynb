# %%
# Let's import the required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
import re

from gensim import corpora
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from sklearn.feature_extraction.text import TfidfVectorizer

from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk import pos_tag
from collections import Counter

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Acquisition

# %%
df=pd.read_csv('train_news.csv')
df
# Out:
#        Unnamed: 0     id                                           headline  \
# 0               0   9653  Ethics Questions Dogged Agriculture Nominee as...
# 1               1  10041  U.S. Must Dig Deep to Stop Argentina’s Lionel ...
# 2               2  19113  Cotton to House: ’Do Not Walk the Plank and Vo...
# 3               3   6868  Paul LePage, Besieged Maine Governor, Sends Co...
# 4               4   7596                       A Digital 9/11 If Trump Wins
# ...           ...    ...                                                ...
# 20795       20795   5671                                                NaN
# 20796       20796  14831        Albert Pike and the European Migrant Crisis
# 20797       20797  18142  Dakota Access Caught Infiltrating Protests to ...
# 20798       20798  12139  How to Stretch the Summer Solstice - The New Y...
# 20799       20799  15660  Emory University to Pay for ’100 Percent’ of U...
#
#                        written_by  \
# 0      Eric Lipton and Steve Eder
# 1                 David Waldstein
# 2                         Pam Key
# 3                    Jess Bidgood
# 4               Finian Cunningham
# ...                           ...
# 20795              NeverSurrender
# 20796               Rixon Stewart
# 20797                 Eddy Lavine
# 20798              Alison S. Cohn
# 20799                Tom Ciccotta
#
#                                                     news  label
# 0      WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0
# 1      HOUSTON  —   Venezuela had a plan. It was a ta...      0
# 2      Sunday on ABC’s “This Week,” while discussing ...      0
# 3      AUGUSTA, Me.  —   The beleaguered Republican g...      0
# 4        Finian Cunningham has written extensively on...      1
# ...                                                  ...    ...
# 20795  No, you'll be a dog licking of the vomit of yo...      1
# 20796  By Rixon Stewart on November 5, 2016 Rixon Ste...      1
# 20797  posted by Eddie You know the Dakota Access Pip...      1
# 20798  It’s officially summer, and the Society Boutiq...      0
# 20799  Emory University in Atlanta, Georgia, has anno...      0
#
# [20800 rows x 6 columns]

# %%
#checking features name
print("Features/Columns :\n", df.columns)
# Out:
# Features/Columns :
#  Index(['Unnamed: 0', 'id', 'headline', 'written_by', 'news', 'label'], dtype='object')

# %%
#checking shape of train dataset
print ('Shape =',df.shape)
# Out:
# Shape = (20800, 6)

# %%
#checking datatype of each feature
print("Data Types :\n", df.dtypes)
# Out:
# Data Types :
#  Unnamed: 0     int64
# id             int64
# headline      object
# written_by    object
# news          object
# label          int64
# dtype: object

# %%
#checking NAN value
print("Contains NaN/Empty cells : ", df.isnull().values.any())
# Out:
# Contains NaN/Empty cells :  True

# %% [markdown]
# - It means that null values are present in the given dataset

# %%
# Let's see how many Null Values are present in each column
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# id               0
# headline       558
# written_by    1957
# news            39
# label            0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# Let's drop Unnamed: 0  & id from dataset as it does not seem important
df.drop(['Unnamed: 0','id'],axis=1,inplace=True)

# %%
df.reset_index(inplace=True)

# %%
# Feature subject is having some null values, in here I am 
# filling 'Written_by' feature with unknown because sometimes there are anonymus authors,...
# filling up empty values in 'headline'  with 'No Headline'
# Dropping empty values in rows because we are detecting fake news here and for this news is needed..

df['written_by'].fillna('Unknown ',inplace=True)
df['headline'].fillna('no headlines ',inplace=True)
df.dropna(subset=['news'],inplace=True)
df.head()
# Out:
#                                             headline  \
# 0  Ethics Questions Dogged Agriculture Nominee as...
# 1  U.S. Must Dig Deep to Stop Argentina’s Lionel ...
# 2  Cotton to House: ’Do Not Walk the Plank and Vo...
# 3  Paul LePage, Besieged Maine Governor, Sends Co...
# 4                       A Digital 9/11 If Trump Wins
#
#                    written_by  \
# 0  Eric Lipton and Steve Eder
# 1             David Waldstein
# 2                     Pam Key
# 3                Jess Bidgood
# 4           Finian Cunningham
#
#                                                 news  label
# 0  WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0
# 1  HOUSTON  —   Venezuela had a plan. It was a ta...      0
# 2  Sunday on ABC’s “This Week,” while discussing ...      0
# 3  AUGUSTA, Me.  —   The beleaguered Republican g...      0
# 4    Finian Cunningham has written extensively on...      1

# %%
# Hetmap for null values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#Ratio
print ('Fake = ', round(len(df[df['label']==1]) / len(df.label),2)*100,'%')
print ('Not Fake  = ', round(len(df[df['label']==0]) / len(df.label),2)*100,'%')
# Out:
# Fake =  50.0 %
# Not Fake  =  50.0 %

# %%
# Checking how many distinct writers are there
df['written_by'].value_counts()
# Out:
# Unknown                               1918
# Pam Key                                243
# admin                                  193
# Jerome Hudson                          166
# Charlie Spiering                       141
#                                       ...
# Naomi Klein                              1
# Dexy                                     1
# Saeed Al-Batati                          1
# Bettie                                   1
# Katie Thomas and Matthew Goldstein       1
# Name: written_by, Length: 4202, dtype: int64

# %%
#New columns for headline, author and news of message and subject
df['length_headline'] = df.headline.str.len()
#df['length_written_by'] = df.written_by.str.len()
df['length_news'] = df.news.str.len()
df.head()
# Out:
#                                             headline  \
# 0  Ethics Questions Dogged Agriculture Nominee as...
# 1  U.S. Must Dig Deep to Stop Argentina’s Lionel ...
# 2  Cotton to House: ’Do Not Walk the Plank and Vo...
# 3  Paul LePage, Besieged Maine Governor, Sends Co...
# 4                       A Digital 9/11 If Trump Wins
#
#                    written_by  \
# 0  Eric Lipton and Steve Eder
# 1             David Waldstein
# 2                     Pam Key
# 3                Jess Bidgood
# 4           Finian Cunningham
#
#                                                 news  label  length_headline  \
# 0  WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0               84
# 1  HOUSTON  —   Venezuela had a plan. It was a ta...      0               72
# 2  Sunday on ABC’s “This Week,” while discussing ...      0              100
# 3  AUGUSTA, Me.  —   The beleaguered Republican g...      0              100
# 4    Finian Cunningham has written extensively on...      1               28
#
#    length_news
# 0         7936
# 1         6112
# 2          425
# 3         6516
# 4         9164

# %%
df['headline'] = df.headline.str.lower()
df['written_by'] = df.written_by.str.lower()
df['news'] = df.news.str.lower()

# %% [raw]
# cols=['headline','news']
# for i in cols:
#     # Replace email addresses with 'email'
#     emails[i] = emails[i].str.replace(r'^.+@[^\.].*\.[a-z]{2,}$',
#                                      'emailaddress')
#
#     # Replace URLs with 'webaddress'
#     emails[i] = emails[i].str.replace(r'^http\://[a-zA-Z0-9\-\.]+\.[a-zA-Z]{2,3}(/\S*)?$',
#                                       'webaddress')
#
#     # Replace money symbols with 'moneysymb' (£ can by typed with ALT key + 156)
#     emails[i] = emails[i].str.replace(r'£|\$', 'dollers')
#
#     # Replace 10 digit phone numbers (formats include paranthesis, spaces, no spaces, dashes) with 'phonenumber'
#     emails[i] = emails[i].str.replace(r'^\(?[\d]{3}\)?[\s-]?[\d]{3}[\s-]?[\d]{4}$',
#                                       'phonenumber')
#
#
#     # Replace numbers with 'numbr'
#     emails[i] = emails[i].str.replace(r'\d+(\.\d+)?', 'numbr')
#
#     # Remove punctuation
#     emails[i] = emails[i].str.replace(r'[^\w\d\s]', ' ')
#
#     # Replace whitespace between terms with a single space
#     emails[i] = emails[i].str.replace(r'\s+', ' ')
#
#     # Remove leading and trailing whitespace
#     emails[i] = emails[i].str.replace(r'^\s+|\s+?$', '')
#
#     #REPLACING SPECIAL CHARACTERS  BY WHITE SPACE
#     emails[i]=emails[i].str.replace(r"[^a-zA-Z0-9]+", " ")
#
#      #REPLACING one or 2  character length word   BY WHITE SPACE
#     emails[i]=emails[i].str.replace(r'\b[a-zA-Z]{1,2}\b', '')

# %% [raw]
# cols=['headline','news']
# for j in cols:
#     # Replace email addresses with 'email'
#     df[j] = df[j].str.replace(r'^.+@[^\.].*\.[a-z]{2,}$',
#                                      'emailaddress')
#
#     # Replace URLs with 'webaddress'
#     df[j] = df[j].str.replace(r'^http\://[a-zA-Z0-9\-\.]+\.[a-zA-Z]{2,3}(/\S*)?$',
#                                       'webaddress')
#
#     # Replace money symbols with 'moneysymb' (£ can by typed with ALT key + 156)
#     df[j] = df[j].str.replace(r'£|\$', 'dollers')
#
#     # Replace 10 digit phone numbers (formats include paranthesis, spaces, no spaces, dashes) with 'phonenumber'
#     df[j] = df[j].str.replace(r'^\(?[\d]{3}\)?[\s-]?[\d]{3}[\s-]?[\d]{4}$',
#                                       'phonenumber')
#
#
#     # Replace numbers with 'numbr'
#     df[j] = df[j].str.replace(r'\d+(\.\d+)?', 'numbr')
#
#     # Remove punctuation
#     df[j] = df[j].str.replace(r'[^\w\d\s]', ' ')
#
#     # Replace whitespace between terms with a single space
#     df[j] = df[j].str.replace(r'\s+', ' ')
#
#     # Remove leading and trailing whitespace
#     df[j] = df[j].str.replace(r'^\s+|\s+?$', '')
#
#
#     #REPLACING SPECIAL CHARACTERS  BY WHITE SPACE
#     df[j] = df[j].str.replace(r"[^a-zA-Z0-9]+", " ")
#
#      #REPLACING one or 2  character length word   BY WHITE SPACE
#     df[j] = df[j].str.replace(r'\b[a-zA-Z]{1,2}\b', '')

# %% [raw]
# # Remove stopwords
# import string
# import nltk
# from nltk.corpus import  stopwords
#
# stop_words = set(stopwords.words('english') + ['u', 'ü', 'ur', '4', '2', 'im', 'dont', 'doin', 'ure'])
#
# # 'headline','written_by','news'
#
# df['headline'] = df['headline'].apply(lambda x: ' '.join(
#     term for term in x.split() if term not in stop_words))
#
# #df['written_by'] = df['written_by'].apply(lambda x: ' '.join(
# #term for term in x.split() if term not in stop_words))
#
# df['news'] = df['news'].apply(lambda x: ' '.join(
#     term for term in x.split() if term not in stop_words))

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# function to filter using POS tagging. This will be called inside the below function
def get_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# Function for data cleaning.
def Processed_data(comments):
    # Replace email addresses with 'email'
    comments=re.sub(r'^.+@[^\.].*\.[a-z]{2,}$',' ', comments)
        
    # Replace 10 digit phone numbers (formats include paranthesis, spaces, no spaces, dashes) with 'phonenumber'
    comments=re.sub(r'^\(?[\d]{3}\)?[\s-]?[\d]{3}[\s-]?[\d]{4}$',' ',comments)
        
    # getting only words(i.e removing all the special characters)
    comments = re.sub(r'[^\w]', ' ', comments) 
        
    # getting only words(i.e removing all the" _ ")
    comments = re.sub(r'[\_]', ' ', comments) 
    
    # getting rid of unwanted characters(i.e remove all the single characters left)
    comments=re.sub(r'\s+[a-zA-Z]\s+', ' ', comments)
    
    # Removing extra whitespaces
    comments=re.sub(r'\s+', ' ', comments, flags=re.I)

    #converting all the letters of the review into lowercase
    comments = comments.lower()
    
    # splitting every words from the sentences
    comments = comments.split()

    # iterating through each words and checking if they are stopwords or not,
    comments=[word for word in comments if not word in set(STOPWORDS)]
    
    # remove empty tokens
    comments = [text for text in comments if len(text) > 0]
    
    # getting pos tag text
    pos_tags = pos_tag(comments)

    # considering words having length more than 3only
    comments = [text for text in comments if len(text) > 3]        
   
    # performing lemmatization operation and passing the word in get_pos function to get filtered using POS
    comments = [(WordNetLemmatizer().lemmatize(text[0], get_pos(text[1])))for text in pos_tags]

   # considering words having length more than 3 only
    comments = [text for text in comments if len(text) > 3]
    comments = ' '.join(comments)
    return comments

# %%
df['clean_headline']=df['headline'].apply(Processed_data)

# %%
df['clean_news']=df['news'].apply(Processed_data)

# %%
df.head()
# Out:
#                                             headline  \
# 0  ethics questions dogged agriculture nominee as...
# 1  u.s. must dig deep to stop argentina’s lionel ...
# 2  cotton to house: ’do not walk the plank and vo...
# 3  paul lepage, besieged maine governor, sends co...
# 4                       a digital 9/11 if trump wins
#
#                    written_by  \
# 0  eric lipton and steve eder
# 1             david waldstein
# 2                     pam key
# 3                jess bidgood
# 4           finian cunningham
#
#                                                 news  label  length_headline  \
# 0  washington  —   in sonny perdue’s telling, geo...      0               84
# 1  houston  —   venezuela had a plan. it was a ta...      0               72
# 2  sunday on abc’s “this week,” while discussing ...      0              100
# 3  augusta, me.  —   the beleaguered republican g...      0              100
# 4    finian cunningham has written extensively on...      1               28
#
#    length_news                                     clean_headline  \
# 0         7936  ethic question dogged agriculture nominee geor...
# 1         6112         deep stop argentina lionel messi york time
# 2          425      cotton house walk plank vote senate breitbart
# 3         6516  paul lepage besieged maine governor sends conf...
# 4         9164                                      digital trump
#
#                                           clean_news
# 0  washington sonny perdue telling georgian growi...
# 1  houston venezuela plan tactical approach desig...
# 2  sunday week discussing republican plan repeal ...
# 3  augusta beleaguered republican governor maine ...
# 4  finian cunningham written extensively internat...

# %% [markdown]
# from nltk.tokenize import RegexpTokenizer
# tokenizer=RegexpTokenizer(r'\w+')
# df['headline'] = df['headline'].apply(lambda x: tokenizer.tokenize(x.lower()))
# df['written_by'] = df['written_by'].apply(lambda x: tokenizer.tokenize(x.lower()))
# df['news'] = df['news'].apply(lambda x: tokenizer.tokenize(x.lower()))
# df.head()

# %%
#df['headline'] = df['clean_headline'].apply(lambda x:' '.join(y for y in x))
#df['written_by'] = df['written_by'].apply(lambda x:' '.join(y for y in x))
#df['news'] = df['clean_news'].apply(lambda x:' '.join(y for y in x))
df['clean_length_headline']=df.clean_headline.str.len()
df['clean_length_news']=df.clean_news.str.len()

df.head(10)
# Out:
#                                             headline  \
# 0  ethics questions dogged agriculture nominee as...
# 1  u.s. must dig deep to stop argentina’s lionel ...
# 2  cotton to house: ’do not walk the plank and vo...
# 3  paul lepage, besieged maine governor, sends co...
# 4                       a digital 9/11 if trump wins
# 5  whatever the outcome on november 8th the us wi...
# 6  rapid evolution saved this fish from pollution...
# 7  alabama prison officials retaliate against pri...
# 8                                      no headlines
# 9           can we live in a constant state of love?
#
#                    written_by  \
# 0  eric lipton and steve eder
# 1             david waldstein
# 2                     pam key
# 3                jess bidgood
# 4           finian cunningham
# 5                    unknown
# 6                joanna klein
# 7            brian sonenstein
# 8                 steventexas
# 9                     gillian
#
#                                                 news  label  length_headline  \
# 0  washington  —   in sonny perdue’s telling, geo...      0               84
# 1  houston  —   venezuela had a plan. it was a ta...      0               72
# 2  sunday on abc’s “this week,” while discussing ...      0              100
# 3  augusta, me.  —   the beleaguered republican g...      0              100
# 4    finian cunningham has written extensively on...      1               28
# 5  taming the corporate media beast whatever the ...      1              106
# 6  the state of new jersey says you can’t eat the...      0               79
# 7  advocates say prison officials at the kilby co...      1               88
# 8  people have made up their minds on president.\...      1               13
# 9  leave a reply \ntoni emerson – when we fall in...      1               40
#
#    length_news                                     clean_headline  \
# 0         7936  ethic question dogged agriculture nominee geor...
# 1         6112         deep stop argentina lionel messi york time
# 2          425      cotton house walk plank vote senate breitbart
# 3         6516  paul lepage besieged maine governor sends conf...
# 4         9164                                      digital trump
# 5        15285  outcome november collision course china federi...
# 6         4159  rapid evolution saved fish pollution study yor...
# 7         6311  alabama prison official retaliate prison strik...
# 8          782                                           headline
# 9         6386                           live constant state love
#
#                                           clean_news  clean_length_headline  \
# 0  washington sonny perdue telling georgian growi...                     68
# 1  houston venezuela plan tactical approach desig...                     42
# 2  sunday week discussing republican plan repeal ...                     45
# 3  augusta beleaguered republican governor maine ...                     80
# 4  finian cunningham written extensively internat...                     13
# 5  taming corporate medium beast outcome november...                     59
# 6  state jersey fish shellfish passaic river newa...                     52
# 7  advocate prison official kilby correctional fa...                     73
# 8  people mind president served elected district ...                      8
# 9  leave reply toni emerson fall love heart feel ...                     24
#
#    clean_length_news
# 0               4803
# 1               3632
# 2                212
# 3               3847
# 4               5888
# 5               9223
# 6               2473
# 7               3494
# 8                449
# 9               3760

# %% [raw]
# from nltk.stem import SnowballStemmer, WordNetLemmatizer
# stemmer = SnowballStemmer("english")
# import gensim
# def lemmatize_stemming(text):
#     return stemmer.stem(WordNetLemmatizer().lemmatize(text,pos='v'))
#
# #Tokenize and Lemmatize
# #def preprocess(text):
#  #   result=[]
#   #  for token in text:
#    #     if len(token)>=3:
#     #        result.append(lemmatize_stemming(token))
#
#     #return result

# %% [raw]
# from nltk.stem.porter import PorterStemmer
# port_stem=PorterStemmer()

# %%
df['comment_text']=lemmatize_stemming(df['headline'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-61-a0909ddbb097> in <module>
# ----> 1 df['comment_text']=lemmatize_stemming(df['headline'])
#       2 df.head()
#
# <ipython-input-60-24ec6db98a94> in lemmatize_stemming(text)
#       1 def lemmatize_stemming(text):
#       2     corpus=[]
# ----> 3     stemmed_content=stemmed_content.lower()
#       4     stemmed_content=stemmed_content.split()
#       5     return stemmer.stem(WordNetLemmatizer().lemmatize(text))
#
# UnboundLocalError: local variable 'stemmed_content' referenced before assignment

# %% [raw]
# df['clean_headline']=df['headline'].apply(stemming)

# %%
# Total length removal
print ('Origian Length', df.length_headline.sum())
print ('Clean Length', df.clean_length_headline.sum())
print('Total Reduction = ',df['length_headline'].sum()-df['clean_length_headline'].sum())
# Out:
# Origian Length 1507844
# Clean Length 1040606
# Total Reduction =  467238

# %%
# Total length removal
print ('Origian Length', df.length_news.sum())
print ('Clean Length', df.clean_length_news.sum())
print('Total Reduction = ',df['length_news'].sum()-df['clean_length_news'].sum())
# Out:
# Origian Length 94518924
# Clean Length 56207800
# Total Reduction =  38311124

# %%
lb=df['label'].value_counts().index.tolist()
val=df['label'].value_counts().values.tolist()
exp=(0.025,0)
clr=('cyan','skyblue')
plt.figure(figsize=(10,6),dpi=140)
sns.set_context('talk',font_scale=0.4)
sns.set(style='whitegrid')
plt.pie(x=val,explode=exp,labels=lb,colors=clr,autopct='%2.0f%%',pctdistance=0.5, shadow=True,radius=0.9)
plt.legend(["0 = NOT FAKE",'1 = FAKE'])
plt.show()

# %%
# news distribution BEFORE cleaning
f,ax = plt.subplots(1,2,figsize = (15,8))

sns.distplot(df[df['label']==1]['length_news'],bins=20,ax=ax[0],label='Fake News distribution',color='r')

ax[0].set_xlabel('Fake News length')
ax[0].legend()

sns.distplot(df[df['label']==0]['length_news'],bins=20,ax=ax[1],label='True News distribution')
ax[1].set_xlabel('True News length')
ax[1].legend()

plt.show()

# %%
# news distribution AFTER cleaning
f,ax = plt.subplots(1,2,figsize = (15,8))

sns.distplot(df[df['label']==1]['clean_length_news'],bins=20,ax=ax[0],label='Fake News distribution',color='r')

ax[0].set_xlabel('Fake News length')
ax[0].legend()

sns.distplot(df[df['label']==0]['clean_length_news'],bins=20,ax=ax[1],label='True News distribution')
ax[1].set_xlabel('True News length')
ax[1].legend()

plt.show()

# %%
#Getting sense of loud words in Fake News - Articles
from wordcloud import WordCloud

fake = df['news'][df['label']==1]

fake_cloud = WordCloud(width=700,height=500,background_color='white',max_words=200).generate(' '.join(fake))

plt.figure(figsize=(10,8),facecolor='r')
plt.imshow(fake_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
#Getting sense of loud words in Not Fake News - Articles
from wordcloud import WordCloud

not_fake = df['news'][df['label']==0]

not_fake_cloud = WordCloud(width=700,height=500,background_color='white',max_words=200).generate(' '.join(not_fake))

plt.figure(figsize=(10,8),facecolor='r')
plt.imshow(not_fake_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
#Getting sense of loud words in Fake News - Headline
from wordcloud import WordCloud

fake = df['headline'][df['label']==1]

fake_cloud = WordCloud(width=700,height=500,background_color='white',max_words=200).generate(' '.join(fake))

plt.figure(figsize=(10,8),facecolor='r')
plt.imshow(fake_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
#Getting sense of loud words in Not Fake News - Headline
from wordcloud import WordCloud

not_fake = df['headline'][df['label']==0]

not_fake_cloud = WordCloud(width=700,height=500,background_color='white',max_words=200).generate(' '.join(not_fake))

plt.figure(figsize=(10,8),facecolor='r')
plt.imshow(not_fake_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
from nltk import tokenize
import seaborn as sns
import numpy as np
# Most Frequent Words in Fake and Real News
token_space = tokenize.WhitespaceTokenizer()

def counter(text, column_text, quantity):
    all_words = ' '.join([text for text in text[column_text]])
    token_phrase = token_space.tokenize(all_words)
    frequency = nltk.FreqDist(token_phrase)
    df_frequency = pd.DataFrame({"Word": list(frequency.keys()),
                                   "Frequency": list(frequency.values())})
    df_frequency = df_frequency.nlargest(columns = "Frequency", n = quantity)
    plt.figure(figsize=(12,8))
    ax = sns.barplot(data = df_frequency, x = "Word", y = "Frequency")
    ax.set(ylabel = "Count")
    plt.xticks(rotation='vertical')
    plt.show()

# %%
counter(df[df["label"] == 0], "news", 20)

# %%
from collections import Counter
#for counting frequently occurence of Negative and Non negative words.
count1 = Counter(" ".join(df[df['label']==1]["clean_headline"]).split()).most_common(50)
count2 = Counter(" ".join(df[df['label']==0]["clean_headline"]).split()).most_common(50)
dataframe=pd.DataFrame()
print("TOP 50 Words in Each Category (Word,Counts)")
dataframe['Most Frequent Words in Negative Comments']=count1
dataframe['Most Frequent Words in Non negative Comments']=count2
dataframe
# Out:
# TOP 50 Words in Each Category (Word,Counts)
#    Most Frequent Words in Negative Comments  \
# 0                             (trump, 1454)
# 1                           (hillary, 1048)
# 2                            (clinton, 975)
# 3                           (headline, 565)
# 4                           (election, 542)
# 5                              (video, 388)
# 6                             (russia, 346)
# 7                               (news, 346)
# 8                            (comment, 334)
# 9                            (america, 311)
# 10                             (email, 305)
# 11                             (world, 286)
# 12                             (obama, 284)
# 13                            (donald, 260)
# 14                          (american, 231)
# 15                              (2016, 213)
# 16                             (state, 200)
# 17                         (wikileaks, 184)
# 18                              (vote, 181)
# 19                          (breaking, 180)
# 20                          (campaign, 176)
# 21                              (year, 172)
# 22                              (time, 171)
# 23                         (president, 171)
# 24                           (russian, 168)
# 25                             (black, 162)
# 26                            (medium, 159)
# 27                             (putin, 155)
# 28                            (people, 142)
# 29                             (voter, 141)
# 30                             (syria, 140)
# 31                              (life, 139)
# 32                            (police, 137)
# 33                            (report, 134)
# 34                             (woman, 131)
# 35                             (right, 131)
# 36                             (white, 126)
# 37                     (investigation, 123)
# 38                            (muslim, 117)
# 39                            (voting, 113)
# 40                             (watch, 112)
# 41                           (million, 108)
# 42                             (child, 108)
# 43                            (attack, 107)
# 44                         (supporter, 107)
# 45                              (like, 106)
# 46                        (government, 103)
# 47                            (source, 102)
# 48                               (anti, 95)
# 49                               (want, 93)
#
#    Most Frequent Words in Non negative Comments
# 0                                  (time, 6378)
# 1                                  (york, 6345)
# 2                             (breitbart, 2399)
# 3                                 (trump, 2274)
# 4                                 (donald, 627)
# 5                                  (obama, 296)
# 6                                (clinton, 293)
# 7                                  (state, 260)
# 8                               (briefing, 233)
# 9                                  (house, 229)
# 10                             (president, 227)
# 11                               (hillary, 215)
# 12                                (attack, 215)
# 13                                  (news, 206)
# 14                                  (year, 199)
# 15                                (report, 196)
# 16                                 (white, 190)
# 17                                 (woman, 186)
# 18                                (russia, 184)
# 19                                (police, 171)
# 20                              (american, 162)
# 21                                (medium, 154)
# 22                               (evening, 149)
# 23                                  (anti, 142)
# 24                                  (plan, 139)
# 25                              (election, 138)
# 26                                (border, 135)
# 27                              (democrat, 133)
# 28                                 (china, 133)
# 29                                 (court, 129)
# 30                                 (syria, 126)
# 31                            (republican, 122)
# 32                                (health, 120)
# 33                                  (case, 116)
# 34                                (leader, 114)
# 35                                  (fake, 114)
# 36                               (america, 113)
# 37                                 (right, 112)
# 38                             (obamacare, 111)
# 39                                  (city, 109)
# 40                            (california, 109)
# 41                                 (north, 107)
# 42                                  (life, 107)
# 43                               (million, 106)
# 44                              (campaign, 105)
# 45                                  (call, 105)
# 46                                 (world, 102)
# 47                                 (watch, 100)
# 48                               (russian, 100)
# 49                                   (deal, 97)

# %%
#for counting frequently occurence of Negative and Non negative words.
count1 = Counter(" ".join(df[df['label']==1]["clean_news"]).split()).most_common(50)
count2 = Counter(" ".join(df[df['label']==0]["clean_news"]).split()).most_common(50)
dataframe=pd.DataFrame()
print("TOP 50 Words in Each Category (Word,Counts)")
dataframe['Most Frequent Words in Negative Comments']=count1
dataframe['Most Frequent Words in Non negative Comments']=count2
dataframe
# Out:
# TOP 50 Words in Each Category (Word,Counts)
#    Most Frequent Words in Negative Comments  \
# 0                            (trump, 20237)
# 1                          (clinton, 20193)
# 2                           (people, 16923)
# 3                            (state, 15435)
# 4                          (hillary, 12769)
# 5                             (time, 12641)
# 6                             (said, 11874)
# 7                             (year, 11806)
# 8                         (american, 10569)
# 9                             (like, 10562)
# 10                         (election, 9696)
# 11                            (world, 9254)
# 12                       (government, 8916)
# 13                        (president, 8783)
# 14                             (2016, 8544)
# 15                          (country, 7673)
# 16                            (right, 7664)
# 17                            (obama, 7549)
# 18                            (email, 6859)
# 19                           (medium, 6824)
# 20                             (know, 6778)
# 21                           (russia, 6746)
# 22                         (campaign, 6253)
# 23                             (news, 5525)
# 24                             (life, 5441)
# 25                          (america, 5366)
# 26                           (donald, 5321)
# 27                            (thing, 5300)
# 28                            (think, 5293)
# 29                             (need, 5259)
# 30                             (want, 5244)
# 31                            (going, 5205)
# 32                        (political, 5105)
# 33                            (white, 5016)
# 34                          (russian, 4953)
# 35                            (power, 4930)
# 36                             (vote, 4888)
# 37                           (united, 4871)
# 38                             (good, 4857)
# 39                             (come, 4739)
# 40                            (party, 4581)
# 41                            (woman, 4537)
# 42                            (force, 4503)
# 43                             (work, 4478)
# 44                            (group, 4362)
# 45                           (report, 4350)
# 46                         (military, 4343)
# 47                           (public, 4328)
# 48                          (million, 4317)
# 49                           (policy, 4288)
#
#    Most Frequent Words in Non negative Comments
# 0                                 (said, 68179)
# 1                                (trump, 36170)
# 2                                (state, 22507)
# 3                                 (year, 21586)
# 4                               (people, 20027)
# 5                                 (time, 18079)
# 6                            (president, 17288)
# 7                                 (like, 16333)
# 8                             (american, 12031)
# 9                               (united, 10194)
# 10                              (country, 9997)
# 11                                 (news, 9422)
# 12                           (government, 9192)
# 13                                (house, 8828)
# 14                             (official, 8825)
# 15                           (republican, 8638)
# 16                              (company, 8630)
# 17                              (clinton, 8293)
# 18                                (woman, 7933)
# 19                                (group, 7894)
# 20                                 (city, 7834)
# 21                                 (week, 7736)
# 22                                (obama, 7552)
# 23                                (right, 7441)
# 24                                (white, 7421)
# 25                             (campaign, 7406)
# 26                                 (work, 7304)
# 27                                (going, 7221)
# 28                                (think, 7099)
# 29                                 (want, 7032)
# 30                                 (told, 6834)
# 31                              (percent, 6833)
# 32                                (world, 6826)
# 33                              (million, 6721)
# 34                             (national, 6622)
# 35                                 (know, 6603)
# 36                                 (york, 6558)
# 37                               (police, 6472)
# 38                                (party, 6443)
# 39                                (month, 6387)
# 40                               (family, 6322)
# 41                                 (life, 6290)
# 42                                 (case, 6227)
# 43                            (including, 6162)
# 44                            (according, 5989)
# 45                            (political, 5953)
# 46                                 (good, 5905)
# 47                               (public, 5851)
# 48                               (member, 5807)
# 49                              (twitter, 5795)

# %%
# 1. Convert text into vectors using TF-IDF
# 3. Split feature and label

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

tf_vec = TfidfVectorizer()
features = tf_vec.fit_transform(df['written_by'] + df['clean_headline'] + df['clean_news'])

X = features
y = df['label']
X.shape
# Out:
# (20761, 192144)

# %% [raw]
# # creating the TF-IDF(term frequency–inverse document frequency) vectorizer function in order to convert the tokens
# #   from the train documents into vectors so that machine can do further processing
# def Tf_idf(text):
#     tfid = TfidfVectorizer(min_df=2)
#     return tfid.fit_transform(text)

# %% [raw]
# # Inserting vectorized values in a variable x, which will be used in training the model
# x=Tf_idf(df['written_by'] + df['clean_headline'] + df['clean_news'])
#
# # checking the shape of the data which is inserted in x which will be used for model training.
# print("Shape of x: ",x.shape)

# %%
# Out:
# <20761x79062 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4647693 stored elements in Compressed Sparse Row format>

# %%
y.shape
# Out:
# (20761,)

# %%
# Importing useful libraries for model training

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier

# Ensemble Techniques...

from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier

# Model selection libraries...
from sklearn.model_selection import cross_val_score, cross_val_predict, train_test_split
from sklearn.model_selection import GridSearchCV

# Importing some metrics we can use to evaluate our model performance.... 
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.metrics import precision_score, recall_score, f1_score

# Creating instances for different Classifiers

RF=RandomForestClassifier()
LR=LogisticRegression()
MNB=MultinomialNB()
DT=DecisionTreeClassifier()
AD=AdaBoostClassifier()
XG=XGBClassifier(eval_metric='mlogloss')

# %%
# List of Models
models=[]
models.append(('LogisticRegression',LR))
models.append(('MultinomialNB()',MNB))
models.append(('DecisionTreeClassifier',DT))
models.append(('RandomForestClassifier',RF))
models.append(('AdaBoostClassifier',AD))
models.append(('XGBClassifier',XG))

# %%
# Finding best Random State and then calculate Maximum Accuracy Score
def max_acc_score(clf,x,y):
    max_acc_score=0
    final_r_state=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=r_state,stratify=y)
        clf.fit(x_train,y_train)
        y_pred=clf.predict(x_test)
        acc_score=accuracy_score(y_test,y_pred)
        if acc_score > max_acc_score:
            max_acc_score=acc_score
            final_r_state=r_state
    print('Max Accuracy Score corresponding to Random State ', final_r_state, 'is:', max_acc_score)
    print('\n')
    return final_r_state

# %%
Model=[]
Score=[]
Acc_score=[]
cvs=[]
rocscore=[]
#            For Loop to Calculate Accuracy Score, Cross Val Score, Classification Report, Confusion Matrix

for name,model in models:
    print('***************************',name,'*****************************')
    print('\n')
    Model.append(name)
    print(model)
    print('\n')
    
     #        Now here I am calling a function which will calculate the max accuracy score for each model 
     #                               and return best random state.
    r_state=max_acc_score(model,X,y)
    x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=r_state,stratify=y)
    model.fit(x_train,y_train)
#..............Learning Score...........
    score=model.score(x_train,y_train)
    print('Learning Score : ',score)
    Score.append(score*100)
    y_pred=model.predict(x_test)
    acc_score=accuracy_score(y_test,y_pred)
    print('Accuracy Score : ',acc_score)
    Acc_score.append(acc_score*100)
#................Finding Cross_val_score..................    
    cv_score=cross_val_score(model,X,y,cv=10,scoring='roc_auc').mean()
    print('Cross Val Score : ', cv_score)
    cvs.append(cv_score*100)
#................Roc auc score...........................    
    false_positive_rate,true_positive_rate, thresholds=roc_curve(y_test,y_pred)
    roc_auc=auc(false_positive_rate, true_positive_rate)
    print('roc auc score : ', roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
#................Classification Report...........................      
    print('Classification Report:\n',classification_report(y_test,y_pred))
    print('\n')
    
    print('Confusion Matrix:\n',confusion_matrix(y_test,y_pred))
    print('\n')
    

    
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC = %0.2f'% roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True_positive_rate')
    plt.xlabel('False_positive_rate')
    print('\n\n')
# Out:
# *************************** LogisticRegression *****************************
#
#
# LogisticRegression()
#
#
# Max Accuracy Score corresponding to Random State  43 is: 0.9478246909616311
#
#
# Learning Score :  0.9685521607486925
# Accuracy Score :  0.9478246909616311
# Cross Val Score :  0.9874621772360532
# roc auc score :  0.9478236737157978
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      3116
#            1       0.95      0.95      0.95      3113
#
#     accuracy                           0.95      6229
#    macro avg       0.95      0.95      0.95      6229
# weighted avg       0.95      0.95      0.95      6229
#
#
#
# Confusion Matrix:
#  [[2960  156]
#  [ 169 2944]]
#
#
#
#
#
# *************************** MultinomialNB() *****************************
#
#
# MultinomialNB()
#
#
# Max Accuracy Score corresponding to Random State  75 is: 0.8402632846363782
#
#
# Learning Score :  0.8843242499311863
# Accuracy Score :  0.8402632846363782
# Cross Val Score :  0.9743016219938256
# roc auc score :  0.8401906453000317
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.99      0.86      3116
#            1       0.99      0.69      0.81      3113
#
#     accuracy                           0.84      6229
#    macro avg       0.87      0.84      0.84      6229
# weighted avg       0.87      0.84      0.84      6229
#
#
#
# Confusion Matrix:
#  [[3088   28]
#  [ 967 2146]]
#
#
#
#
#
# *************************** DecisionTreeClassifier *****************************
#
#
# DecisionTreeClassifier()
#
#
# Max Accuracy Score corresponding to Random State  89 is: 0.9338577620805908
#
#
# Learning Score :  1.0
# Accuracy Score :  0.9351420773799968
# Cross Val Score :  0.9318925672300674
# roc auc score :  0.9351417530608936
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94      3116
#            1       0.94      0.93      0.94      3113
#
#     accuracy                           0.94      6229
#    macro avg       0.94      0.94      0.94      6229
# weighted avg       0.94      0.94      0.94      6229
#
#
#
# Confusion Matrix:
#  [[2916  200]
#  [ 204 2909]]
#
#
#
#
#
# *************************** RandomForestClassifier *****************************
#
#
# RandomForestClassifier()
#
#
# Max Accuracy Score corresponding to Random State  53 is: 0.9325734467811848
#
#
# Learning Score :  1.0
# Accuracy Score :  0.924707015572323
# Cross Val Score :  0.9822468142714621
# roc auc score :  0.9246919209559317
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93      3116
#            1       0.95      0.89      0.92      3113
#
#     accuracy                           0.92      6229
#    macro avg       0.93      0.92      0.92      6229
# weighted avg       0.93      0.92      0.92      6229
#
#
#
# Confusion Matrix:
#  [[2979  137]
#  [ 332 2781]]
#
#
#
#
#
# *************************** AdaBoostClassifier *****************************
#
#
# AdaBoostClassifier()
#
#
# Max Accuracy Score corresponding to Random State  50 is: 0.9442928238882645
#
#
# Learning Score :  0.9439168731076245
# Accuracy Score :  0.9442928238882645
# Cross Val Score :  0.9846652201519082
# roc auc score :  0.9442925790104605
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      3116
#            1       0.94      0.94      0.94      3113
#
#     accuracy                           0.94      6229
#    macro avg       0.94      0.94      0.94      6229
# weighted avg       0.94      0.94      0.94      6229
#
#
#
# Confusion Matrix:
#  [[2944  172]
#  [ 175 2938]]
#
#
#
#
#
# *************************** XGBClassifier *****************************
#
#
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               random_state=None, reg_alpha=None, reg_lambda=None,
#               scale_pos_weight=None, subsample=None, tree_method=None,
#               validate_parameters=None, verbosity=None)
#
#
# [20:49:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:51:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:53:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:54:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:56:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:58:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:00:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:02:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:04:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:06:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:07:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:10:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:11:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:13:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:15:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:17:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:18:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:46:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:47:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:49:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:51:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:52:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:54:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:56:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:58:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:59:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:01:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:03:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:04:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:06:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:08:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:10:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:11:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:13:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:15:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:16:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:18:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:20:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:21:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:23:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:25:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:26:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:28:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:30:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:32:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:33:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:35:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:37:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:38:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:40:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:42:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:43:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:45:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:47:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:49:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:52:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:54:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Max Accuracy Score corresponding to Random State  83 is: 0.9723872210627709
#
#
# [09:55:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning Score :  0.9988989815579411
# Accuracy Score :  0.9723872210627709
# [09:57:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:59:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:01:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:04:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:06:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:08:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:10:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:13:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:15:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:17:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Cross Val Score :  0.995435362520333
# roc auc score :  0.9723867507454556
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      3116
#            1       0.97      0.97      0.97      3113
#
#     accuracy                           0.97      6229
#    macro avg       0.97      0.97      0.97      6229
# weighted avg       0.97      0.97      0.97      6229
#
#
#
# Confusion Matrix:
#  [[3033   83]
#  [  89 3024]]

# %%
scores=pd.DataFrame({'Model': Model,'Learning Score': Score,'Accuracy Score': Acc_score,'Cross Val Score':cvs,
                     'Roc_Auc_curve':rocscore}) 
scores.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row0_col1{
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row0_col2,#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row0_col4{
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row0_col3{
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row1_col1,#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row1_col2,#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row1_col4,#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row2_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row1_col3{
#             background-color:  #2685bb;
#             color:  #000000;
#         }#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row2_col1,#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row3_col1,#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row5_col2,#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row5_col3,#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row5_col4{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row2_col2,#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row2_col4{
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row3_col2,#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row3_col4{
#             background-color:  #308cbe;
#             color:  #000000;
#         }#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row3_col3{
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row4_col1{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row4_col2,#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row4_col4{
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row4_col3{
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }#T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row5_col1{
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }</style><table id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Learning Score</th>        <th class="col_heading level0 col2" >Accuracy Score</th>        <th class="col_heading level0 col3" >Cross Val Score</th>        <th class="col_heading level0 col4" >Roc_Auc_curve</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row0_col0" class="data row0 col0" >LogisticRegression</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row0_col1" class="data row0 col1" >96.855216</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row0_col2" class="data row0 col2" >94.782469</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row0_col3" class="data row0 col3" >98.746218</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row0_col4" class="data row0 col4" >94.782367</td>
#             </tr>
#             <tr>
#                         <th id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row1_col0" class="data row1 col0" >MultinomialNB()</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row1_col1" class="data row1 col1" >88.432425</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row1_col2" class="data row1 col2" >84.026328</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row1_col3" class="data row1 col3" >97.430162</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row1_col4" class="data row1 col4" >84.019065</td>
#             </tr>
#             <tr>
#                         <th id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row2_col0" class="data row2 col0" >DecisionTreeClassifier</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row2_col1" class="data row2 col1" >100.000000</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row2_col2" class="data row2 col2" >93.514208</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row2_col3" class="data row2 col3" >93.189257</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row2_col4" class="data row2 col4" >93.514175</td>
#             </tr>
#             <tr>
#                         <th id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row3_col0" class="data row3 col0" >RandomForestClassifier</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row3_col1" class="data row3 col1" >100.000000</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row3_col2" class="data row3 col2" >92.470702</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row3_col3" class="data row3 col3" >98.224681</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row3_col4" class="data row3 col4" >92.469192</td>
#             </tr>
#             <tr>
#                         <th id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row4_col0" class="data row4 col0" >AdaBoostClassifier</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row4_col1" class="data row4 col1" >94.391687</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row4_col2" class="data row4 col2" >94.429282</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row4_col3" class="data row4 col3" >98.466522</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row4_col4" class="data row4 col4" >94.429258</td>
#             </tr>
#             <tr>
#                         <th id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row5_col0" class="data row5 col0" >XGBClassifier</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row5_col1" class="data row5 col1" >99.889898</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row5_col2" class="data row5 col2" >97.238722</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row5_col3" class="data row5 col3" >99.543536</td>
#                         <td id="T_2f982f1c_cd95_11eb_9d18_3ca067db61e4row5_col4" class="data row5 col4" >97.238675</td>
#             </tr>
#     </tbody></table>

# %%
sns.barplot(y=Model,x=Acc_score)
# Out:
# <AxesSubplot:>

# %% [markdown]
# pdf link
# https://stackoverflow.com/questions/66097701/how-can-i-fix-this-warning-in-xgboost

# %%
# Using XGBClassifier for final model...
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=83,test_size=.30)
XG=XGBClassifier(eval_metric='mlogloss')
XG.fit(x_train,y_train)
XG.score(x_train,y_train)
XGpred=XG.predict(x_test)
print('Accuracy Score:','\n',accuracy_score(y_test,XGpred))
print('Confusion Matrix:',confusion_matrix(y_test,XGpred))
print('Classification Report:','\n',classification_report(y_test,XGpred))
# Out:
# Accuracy Score:
#  0.9680526569272756
# Confusion Matrix: [[3011  108]
#  [  91 3019]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      3119
#            1       0.97      0.97      0.97      3110
#
#     accuracy                           0.97      6229
#    macro avg       0.97      0.97      0.97      6229
# weighted avg       0.97      0.97      0.97      6229

# %%
# Make predictions with probabilities
y_probs = XG.predict_proba(x_test)

# Keep the probabilites of the positive class only
y_probs = y_probs[:, 1]

# Calculate fpr, tpr and thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_probs)

# Check the false positive rate
fpr
plt.plot([0,1],[0,1])
plt.plot(fpr,tpr,label='XGB Classifier')
plt.xlabel('false positive rate')
plt.ylabel('True positive rate')
plt.title('XGB Classifier')
plt.show()
print('roc_auc_score = ',roc_auc_score(y_test, y_probs))
# Out:
# roc_auc_score =  0.995268291325132

# %%
# Printing predicted values
test=pd.DataFrame(data=y_test,)
test['Predicted values']=XGpred
test
# On the lest side values are those which are taken by machine for test...
# Out:
#        label  Predicted values
# 15556      1                 1
# 11095      0                 0
# 7102       1                 1
# 9496       0                 0
# 7047       0                 0
# ...      ...               ...
# 8361       0                 0
# 181        1                 1
# 2106       1                 1
# 14777      1                 1
# 15724      1                 1
#
# [6229 rows x 2 columns]
